# %% [markdown]
# <a href="https://colab.research.google.com/github/davanstrien/Computer-Vision-for-the-Humanities-workshop/blob/main/more_cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install transformers

# %%
# zero shot image classification

# %%
from transformers import pipeline
import requests
from PIL import Image

checkpoint = "openai/clip-vit-large-patch14"
detector = pipeline(model=checkpoint, task="zero-shot-image-classification")
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# ...

# %%
url = 'https://datasets-server.huggingface.co/cached-assets/biglam/illustrated_ads/--/688e7d96e99cd5730a17a5c55b0964d27a486904/--/default/train/0/image/image.jpg?Expires=1707933334&Signature=x8tVk7bUaSTctiUIqyOPQOwSC0GCKEzIj9VWst~8X2Uv6CR1P~ouW82rYaQfZ6niL3V8q~3B6kgzSm1ELmMr0OeZXQjr9HkeIHzl-wVypM3YNRfTFlfI1s4sdGQifIr3FCIvnXSBlczstW-FdnCIUf4lLA9Vrq8Ats5~kt8tUTr5BB8hf5yo9PbBr4Q1YJKBWM1xlb8Ka~vz9pybnCV-FB04tHJkbc2pM1VkGncgbF7t0s8WgAO08K-Vk0os4dS9NXl1FU3ErYfB0bTWicNkA7aq2PItpJ3Dfwo-YeNWsdt4UagQltnE8agm9~a7mr-NfFJ2K1jGHujz-hYVus~gJA__&Key-Pair-Id=K3EI6M078Z3AC3'

# %%
image = Image.open(requests.get(url, stream=True).raw)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=388x395>

# %%
predictions = detector(image, candidate_labels=["illustrated", "text only"])
predictions
# Out:
# [{'score': 0.9606096148490906, 'label': 'text only'},
#  {'score': 0.039390359073877335, 'label': 'illustrated'}]

# %%
url = "https://datasets-server.huggingface.co/assets/biglam/illustrated_ads/--/default/train/34/image/image.jpg?Expires=1707933117&Signature=GAOuh~x8JZqLgbwvbpsIt0w9Hiq9heIeEI9UjFVXVlssZsOHURDeNCMnn74FTN8pFqnLV4EBC7yCs7AQSrTUH~-ucIa9lPOOkGkkF2mDJrL2ltJw4XVGaRZADduvGMl0aptddrIYs-I0pS20d3344IHfA3u05SksN82T-nRnF7PlVRQ~-iaUtrDg3ur0X~aNdwRmY7b9q2atenKa8uHLrpxWaKJDpxqtJz2To7N-rWlsNZAGk7Mizt8MI9VF7QKJJxnIQi5moKjSkVgWhhmw3wV73LHFFLmRSuUxU7Qy5O7HQHi1gGp6D6Ii1m05XF8saHRTgwHPh~vwieJ7~aEteA__&Key-Pair-Id=K3EI6M078Z3AC3"

# %%
image = Image.open(requests.get(url, stream=True).raw)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=711x595>

# %%
predictions = detector(image, candidate_labels=["illustrated", "text only"])
predictions
# Out:
# [{'score': 0.8299923539161682, 'label': 'text only'},
#  {'score': 0.1700076162815094, 'label': 'illustrated'}]

# %%
# object detection

# %%
# zero shot object detection

# %%
from transformers import pipeline

checkpoint = "google/owlvit-base-patch32"
detector = pipeline(model=checkpoint, task="zero-shot-object-detection")
